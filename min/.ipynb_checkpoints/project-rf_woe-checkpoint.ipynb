# %%
from badsproject import BADS

#####################################
#
#  Variable Selection
#
#####################################
params_rf = {
    ######### Set Seed #########
    "rs": 90049,
    "save_model": False,

    ######### Feature Selection #########
    "manual_features_to_remove": ["x_order_date_num", "x_account_creation_date_num", 
                                  "x_deliverydate_estimated_num", "x_deliverydate_actual_num"],
    "feature_correlation_removal": True,
    "feature_correlation_threshold": 0.7,
    "automatic_feature_selection": True,
    "automatic_feature_threshold": 0.005,

    ######### Oversampling #########
    # non-standard package: http://contrib.scikit-learn.org/imbalanced-learn/index.html
    "oversample_method": "none",

    ######### Cross-Valdiation #########
    "do_cv": False, # this takes a long time
    "cv_num_folds": 8,
    "cv_validation_frac": 0.15,
    "cv_rs_iters": 10,

    ######### Model Selection #########
    "model_to_use": "rf", # "rf" or "gbc" or "linear"
}

a = BADS()
a.set_model("rf")
a.__dict__.update(params_rf)
# Load and split training  and testing data and create cross validation sets from training data
a.create_datasets(use_woe = False)
# Oversample if desired
a.oversample()
# Run algorithm-based feature selection
a.automagic_feature_selection()
# Print size of training sets
print(a.X_train.shape, a.X_test.shape, a.X_train_cv.shape, a.X_valid_cv.shape)
# Run the models
a.run_model("output/8_rf_fs.csv")
# Out:
# Removing correlated features...
# Removing Columns: deliverydate_actual, x_tot_canceled_remitted, account_creation_date, x_hardware_count_bin_1, x_audiobook_download_count_bin_0, x_remitted, x_advertising_code_bin_C, x_schoolbook_count_bin_1, postcode_delivery_1, x_ebook_count_bin_2, x_book_count_bin_1, x_advertising_code_bin_Other, x_other_count_bin_1, x_audiobook_count_bin_1, x_audiobook_download_count_bin_1, form_of_address_Other, x_remitted_all, x_used_items_bin_0, x_ebook_count_bin_1, x_paperback_count_bin_1, x_used_items_bin_2, x_ebook_count_bin_0, x_advertising_code_bin_B, x_musical_count_bin_1, x_delivery_time_est_bin_5, x_hardware_count_bin_0, x_imported_count_bin_1, payment_Cash payment, x_film_count_bin_1, x_delivery_time_est, model_1, x_used_items_bin_1, x_canceled, x_audiobook_download_count_bin_2
# Imposing train column structure on test...
# No oversampling...
# Starting automatic feature selection...
# High Importance Features: order_date, newsletter, delivery, coupon, goods_value, referrer, cost_shipping, deliverydate_estimated, weight, remitted_items, book_count, paperback_count, schoolbook_count, audiobook_download_count, imported_count, x_timelapse_creat_order, x_deliverydate_gap, x_delivery_time, x_item_count, x_item_multiple, x_buyer_human, x_order_date_is_weekday, form_of_address_Mr, form_of_address_Mrs, email_domain_gmx.de, email_domain_other, email_domain_t-online.de, email_domain_web.de, email_domain_yahoo.de, model_2, model_3, payment_Invoice, payment_Transfer from credit card, payment_Transfer from current account, advertising_code_BQ, advertising_code_Other, x_delivery_time_est_bin_0, x_delivery_time_est_bin_1, x_book_count_bin_0, x_paperback_count_bin_0
# (51884, 40) (12971, 40) (44101, 40) (7783, 40)
# Validation Summary:
# Calculate Optimal Threshold
# Threshold: 0.24
# Average ROI: 0.792496466658
# ROC Score: 0.64512723738
# Validation Return Customers: 1853 of 7783 (23.81%)
# [[5036 1281]
#  [ 894  572]]
# Testing Return Customers: 3125 of 12971 (24.09%)
